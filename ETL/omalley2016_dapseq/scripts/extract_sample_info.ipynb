# %%
import pandas as pd
import numpy as np

# %%
# task specific imports
from Bio import Entrez

# %%
SERIES_ACCESSION = "GSE60143"

# %%
Entrez.email = "carissa.bleker@nib.si"

# %%
# Get series UID
handle = Entrez.esearch(db="gds", term=f"{SERIES_ACCESSION}[Accession] AND gse[Filter]", field="acc", retmax=1)
series_result = Entrez.read(handle)
series_result
# Out:
# {'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['200060143'], 'TranslationSet': [], 'TranslationStack': [{'Term': 'GSE60143[Accession]', 'Field': 'Accession', 'Count': '944', 'Explode': 'N'}, {'Term': 'gse[Filter]', 'Field': 'Filter', 'Count': '224215', 'Explode': 'N'}, 'AND'], 'QueryTranslation': 'GSE60143[Accession] AND gse[Filter]'}

# %%
series_uid = series_result["IdList"][0]
series_uid
# Out:
# '200060143'

# %%
# Get samples from the series
handle = Entrez.esummary(db="gds", id=series_uid, retmax=1000)
series_result = Entrez.read(handle)
series_result
# Out:
# [{'Item': [], 'Id': '200060143', 'Accession': 'GSE60143', 'GDS': '', 'title': 'In vitro, genomic context identification of transcription factor binding sites', 'summary': 'This SuperSeries is composed of the SubSeries listed below.', 'GPL': '17639;17628', 'GSE': '60143', 'taxon': 'Zea mays; Arabidopsis thaliana', 'entryType': 'GSE', 'gdsType': 'Other; Genome binding/occupancy profiling by high throughput sequencing', 'ptechType': '', 'valType': '', 'SSInfo': '', 'subsetInfo': '', 'PDAT': '2016/05/25', 'suppFile': 'NARROWPEAK', 'Samples': [{'Accession': 'GSM1925639', 'Title': 'SBP_tnt.SPL9_col_a'}, {'Accession': 'GSM1925722', 'Title': 'WRKY_tnt.WRKY47_col_a'}, {'Accession': 'GSM1925888', 'Title': 'NAC_tnt.VND4_col_v3a'}, {'Accession': 'GSM1925473', 'Title': 'MYB_tnt.MYB77_col_a'}, {'Accession': 'GSM1925390', 'Title': 'LOBAS2_tnt.LBD23_colamp_a'}, {'Accession': 'GSM1925261', 'Title': 'C3H_tnt.At1g70910_col_a'}, {'Accession': 'GSM1925075', 'Title': 'AP2EREBP_tnt.DEAR5_colamp_a'}, {'Accession': 'GSM1925178', 'Title': 'C2C2dof_tnt.Adof1_colamp_a'}, {'Accession': 'GSM1925573', 'Title': 'NAC_tnt.ANAC103_colamp_a'}, {'Accession': 'GSM1925287', 'Title': 'EIL_tnt.EIN3_colamp_a'}, {'Accession': 'GSM1925158', 'Title': 'BZR_tnt.At4g36780_colamp_a'}, {'Accession': 'GSM1925805', 'Title': 'bZIP_tnt.bZIP50_col_v31'}, {'Accession': 'GSM1925078', 'Title': 'AP2EREBP_tnt.DREB19_col_a'}, {'Accession': 'GSM1925556', 'Title': 'NAC_tnt.ANAC057_col_a'}, {'Accession': 'GSM1925344', 'Title': 'HSF_tnt.HSF3_col_a'}, {'Accession': 'GSM1925307', 'Title': 'G2like_tnt.At2g03500_colamp_a'}, {'Accession': 'GSM1925656', 'Title': 'TCP_tnt.TCP17_col_a'}, {'Accession': 'GSM1925453', 'Title': 'MYB_tnt.MYB52_col_a'}, {'Accession': 'GSM1925739', 'Title': 'ZFHD_tnt.ATHB24_col_a'}, {'Accession': 'GSM1925370', 'Title': 'Homeobox_tnt.HAT2_colamp_a'}, {'Accession': 'GSM1925241', 'Title': 'C2H2_tnt.IDD4_col_a'}, {'Accession': 'GSM1925407', 'Title': 'MYB_tnt.ATY13_colamp_a'}, {'Accession': 'GSM1925058', 'Title': 'AP2EREBP_tnt.CBF3_colamp_a'}, {'Accession': 'GSM1925490', 'Title': 'MYBrelated_tnt.AT1G18960_col_a'}, {'Accession': 'GSM1925204', 'Title': 'C2C2dof_tnt.dof45_col_a'}, {'Accession': 'GSM1925121', 'Title': 'AP2EREBP_tnt.PLT3_col_a'}, {'Accession': 'GSM1925095', 'Title': 'AP2EREBP_tnt.ERF15_colamp_a'}, {'Accession': 'GSM1925510', 'Title': 'MYBrelated_tnt.At3g09600_col_a'}, {'Accession': 'GSM1925427', 'Title': 'MYB_tnt.MYB119_colamp_a'}, {'Accession': 'GSM1925224', 'Title': 'C2H2_tnt.AT3G46070_col_a'}, {'Accession': 'GSM1925141', 'Title': 'ARID_tnt.AT1G20910_col_a'}, {'Accession': 'GSM1925891', 'Title': 'RAV_tnt.RAV1_col_b'}, {'Accession': 'GSM1925038', 'Title': 'AP2EREBP_tnt.At1g75490_col_a'}, {'Accession': 'GSM1925679', 'Title': 'Trihelix_tnt.GT3a_col_a'}, {'Accession': 'GSM1925536', 'Title': 'NAC_tnt.ANAC005_col_a'}, {'Accession': 'GSM1925324', 'Title': 'HB_tnt.ANL2_colamp_a'}, {'Accession': 'GSM1925012', 'Title': 'AP2EREBP_tnt.ABR1_col_a'}, {'Accession': 'GSM1925788', 'Title': 'bZIP_tnt.TGA9_colamp_a'}, {'Accession': 'GSM1925845', 'Title': 'Homeobox_tnt.EDT1_col200_a'}, {'Accession': 'GSM1925725', 'Title': 'WRKY_tnt.WRKY55_col_a'}, {'Accession': 'GSM1925576', 'Title': 'NAC_tnt.AT3G12910_col_a'}, {'Accession': 'GSM1925808', 'Title': 'bZIP_tnt.bZIP53_colamp_a'}, {'Accession': 'GSM1925559', 'Title': 'NAC_tnt.ANAC062_colamp_a'}, {'Accession': 'GSM1925762', 'Title': 'bHLH_tnt.bHLH64_col_a'}, {'Accession': 'GSM1925865', 'Title': 'NAC_tnt.ANAC034_col_v3b'}, {'Accession': 'GSM1925871', 'Title': 'NAC_tnt.ANAC053_col_v3b'}, {'Accession': 'GSM1925579', 'Title': 'NAC_tnt.CUC1_colamp_a'}, {'Accession': 'GSM1925115', 'Title': 'AP2EREBP_tnt.ESE1_col_a'}, {'Accession': 'GSM1925782', 'Title': 'bZIP_tnt.TGA3_colamp_a'}, {'Accession': 'GSM1925496', 'Title': 'MYBrelated_tnt.AT4G12670_colamp_a'}, {'Accession': 'GSM1925742', 'Title': 'ZFHD_tnt.ATHB33_colamp_a'}, {'Accession': 'GSM1925908', 'Title': 'WRKY_tnt.WRKY70_col200_a'}, {'Accession': 'GSM1925659', 'Title': 'TCP_tnt.TCP24_colamp_a'} ...

# %%
samples = series_result[0]['Samples']
len(samples)
# Out:
# 941

# %%
all_sample_details = {}
failed_samples = []
for s in samples:
    try:
        # Get sample UID
        handle = Entrez.esearch(db="gds", term=f"{s['Accession']}[Accession] AND gsm[Filter]", field="acc", retmax=1)
        sample = Entrez.read(handle)
        sample_uid = sample["IdList"][0]
        # Get sample details
        handle = Entrez.esummary(db="gds", id=sample_uid, retmax=100)
        sample_details = Entrez.read(handle)[0]
        all_sample_details[s["Accession"]] = sample_details
    except:
        print(s)
        failed_samples.append(s)

# %%
import json

# %%
with open("./tmp_sample_info_dump.json", "w") as f: json.dump(all_sample_details, f)

# %%
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.from_dict.html#
pd.DataFrame.from_dict(all_sample_details, orient="index").to_csv("sample")
# Out:
#            Item         Id   Accession GDS                           title  \
# GSM1925639   []  301925639  GSM1925639                  SBP_tnt.SPL9_col_a
# GSM1925722   []  301925722  GSM1925722               WRKY_tnt.WRKY47_col_a
# GSM1925888   []  301925888  GSM1925888                NAC_tnt.VND4_col_v3a
# GSM1925473   []  301925473  GSM1925473                 MYB_tnt.MYB77_col_a
# GSM1925390   []  301925390  GSM1925390           LOBAS2_tnt.LBD23_colamp_a
# ...         ...        ...         ...  ..                             ...
# GSM1925497   []  301925497  GSM1925497      MYBrelated_tnt.AT4G12670_col_a
# GSM1925102   []  301925102  GSM1925102             AP2EREBP_tnt.ERF4_col_a
# GSM1925700   []  301925700  GSM1925700            WRKY_tnt.WRKY27_colamp_a
# GSM1925285   []  301925285  GSM1925285                E2FDP_tnt.E2FC_col_a
# GSM1925202   []  301925202  GSM1925202             C2C2dof_tnt.dof43_col_a
#
#                summary    GPL          GSE                 taxon entryType  \
# GSM1925639  young leaf  17639  60141;60143  Arabidopsis thaliana       GSM
# GSM1925722  young leaf  17639  60141;60143  Arabidopsis thaliana       GSM
# GSM1925888  young leaf  17639  60141;60143  Arabidopsis thaliana       GSM
# GSM1925473  young leaf  17639  60141;60143  Arabidopsis thaliana       GSM
# GSM1925390  young leaf  17639  60141;60143  Arabidopsis thaliana       GSM
# ...                ...    ...          ...                   ...       ...
# GSM1925497  young leaf  17639  60141;60143  Arabidopsis thaliana       GSM
# GSM1925102  young leaf  17639  60141;60143  Arabidopsis thaliana       GSM
# GSM1925700  young leaf  17639  60141;60143  Arabidopsis thaliana       GSM
# GSM1925285  young leaf  17639  60141;60143  Arabidopsis thaliana       GSM
# GSM1925202  young leaf  17639  60141;60143  Arabidopsis thaliana       GSM
#
#             ...                                       ExtRelations n_samples  \
# GSM1925639  ...  [{'RelationType': 'SRA', 'TargetObject': 'SRX1...         0
# GSM1925722  ...  [{'RelationType': 'SRA', 'TargetObject': 'SRX1...         0
# GSM1925888  ...  [{'RelationType': 'SRA', 'TargetObject': 'SRX1...         0
# GSM1925473  ...  [{'RelationType': 'SRA', 'TargetObject': 'SRX1...         0
# GSM1925390  ...  [{'RelationType': 'SRA', 'TargetObject': 'SRX1...         0
# ...         ...                                                ...       ...
# GSM1925497  ...  [{'RelationType': 'SRA', 'TargetObject': 'SRX1...         0
# GSM1925102  ...  [{'RelationType': 'SRA', 'TargetObject': 'SRX1...         0
# GSM1925700  ...  [{'RelationType': 'SRA', 'TargetObject': 'SRX1...         0
# GSM1925285  ...  [{'RelationType': 'SRA', 'TargetObject': 'SRX1...         0
# GSM1925202  ...  [{'RelationType': 'SRA', 'TargetObject': 'SRX1...         0
#
#            SeriesTitle PlatformTitle PlatformTaxa SamplesTaxa PubMedIds  \
# GSM1925639                                                           []
# GSM1925722                                                           []
# GSM1925888                                                           []
# GSM1925473                                                           []
# GSM1925390                                                           []
# ...                ...           ...          ...         ...       ...
# GSM1925497                                                           []
# GSM1925102                                                           []
# GSM1925700                                                           []
# GSM1925285                                                           []
# GSM1925202                                                           []
#
#            Projects                                            FTPLink GEO2R
# GSM1925639       []  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM1925...
# GSM1925722       []  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM1925...
# GSM1925888       []
# GSM1925473       []  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM1925...
# GSM1925390       []  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM1925...
# ...             ...                                                ...   ...
# GSM1925497       []  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM1925...
# GSM1925102       []  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM1925...
# GSM1925700       []  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM1925...
# GSM1925285       []  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM1925...
# GSM1925202       []  ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM1925...
#
# [941 rows x 29 columns]

# %%
failed_samples
# Out:
# []
